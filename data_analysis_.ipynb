# %% [markdown]
# LOADING OF DATA THROUGH GITHUB

# %%
# !git clone https://github.com/rishitha-c-k/Placement-success-dashboard-.git
# Out:
# Cloning into 'Placement-success-dashboard-'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), 638.02 KiB | 2.37 MiB/s, done.

# %%
# !ls
# Out:
# Placement-success-dashboard-

# %%
# !ls Placement-success-dashboard-/
# Out:
# test.csv.csv  train.csv

# %% [markdown]
# READ THE GIT LINK USING PANDAS

# %%
import pandas as pd

df = pd.read_csv('/content/Placement-success-dashboard-/train.csv')
df.head()
# Out:
#    Student_ID  Age  Gender  Degree Branch  CGPA  Internships  Projects  \
# 0        1048   22  Female  B.Tech    ECE  6.29            0         3
# 1       37820   20  Female     BCA    ECE  6.05            1         4
# 2       49668   22    Male     MCA     ME  7.22            1         4
# 3       19467   22    Male     MCA     ME  7.78            2         4
# 4       23094   20  Female  B.Tech     ME  7.63            1         4
#
#    Coding_Skills  Communication_Skills  Aptitude_Test_Score  \
# 0              4                     6                   51
# 1              6                     8                   59
# 2              6                     6                   58
# 3              6                     6                   90
# 4              6                     5                   79
#
#    Soft_Skills_Rating  Certifications  Backlogs Placement_Status
# 0                   5               1         3       Not Placed
# 1                   8               2         1       Not Placed
# 2                   6               2         2       Not Placed
# 3                   4               2         0           Placed
# 4                   6               2         0           Placed

# %%
import pandas as pd

df = pd.read_csv('/content/Placement-success-dashboard-/train.csv')
display(df.head())
# Out:
#    Student_ID  Age  Gender  Degree Branch  CGPA  Internships  Projects  \
# 0        1048   22  Female  B.Tech    ECE  6.29            0         3
# 1       37820   20  Female     BCA    ECE  6.05            1         4
# 2       49668   22    Male     MCA     ME  7.22            1         4
# 3       19467   22    Male     MCA     ME  7.78            2         4
# 4       23094   20  Female  B.Tech     ME  7.63            1         4
#
#    Coding_Skills  Communication_Skills  Aptitude_Test_Score  \
# 0              4                     6                   51
# 1              6                     8                   59
# 2              6                     6                   58
# 3              6                     6                   90
# 4              6                     5                   79
#
#    Soft_Skills_Rating  Certifications  Backlogs Placement_Status
# 0                   5               1         3       Not Placed
# 1                   8               2         1       Not Placed
# 2                   6               2         2       Not Placed
# 3                   4               2         0           Placed
# 4                   6               2         0           Placed

# %% [markdown]
# **DATA CLEANING **

# %%
df.tail(8)
# Out:
#        Student_ID  Age  Gender  Degree Branch  CGPA  Internships  Projects  \
# 44992       49628   22  Female     BCA     IT  6.26            0         3
# 44993       41608   24    Male    B.Sc    ECE  7.13            1         4
# 44994       17135   23    Male     BCA    ECE  6.30            0         4
# 44995        9362   20    Male     MCA  Civil  7.84            2         5
# 44996        8940   19  Female    B.Sc     ME  8.28            1         4
# 44997       13097   20  Female    B.Sc  Civil  8.88            0         4
# 44998       12958   24  Female     MCA    ECE  5.90            1         3
# 44999        9565   23  Female  B.Tech     ME  6.28            0         4
#
#        Coding_Skills  Communication_Skills  Aptitude_Test_Score  \
# 44992              4                    10                   53
# 44993              5                     6                   94
# 44994              7                     4                   65
# 44995              9                     7                   68
# 44996              6                     5                   74
# 44997              4                     5                   83
# 44998              6                     6                   60
# 44999              6                     6                   64
#
#        Soft_Skills_Rating  Certifications  Backlogs Placement_Status
# 44992                   7               1         1       Not Placed
# 44993                   4               2         0           Placed
# 44994                   5               2         3       Not Placed
# 44995                   6               3         1           Placed
# 44996                   5               2         0           Placed
# 44997                   4               2         0       Not Placed
# 44998                   2               2         1       Not Placed
# 44999                   7               2         3       Not Placed

# %%
df.shape
# Out:
# (45000, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Student_ID            45000 non-null  int64
#  1   Age                   45000 non-null  int64
#  2   Gender                45000 non-null  object
#  3   Degree                45000 non-null  object
#  4   Branch                45000 non-null  object
#  5   CGPA                  45000 non-null  float64
#  6   Internships           45000 non-null  int64
#  7   Projects              45000 non-null  int64
#  8   Coding_Skills         45000 non-null  int64
#  9   Communication_Skills  45000 non-null  int64
#  10  Aptitude_Test_Score   45000 non-null  int64
#  11  Soft_Skills_Rating    45000 non-null  int64
#  12  Certifications        45000 non-null  int64
#  13  Backlogs              45000 non-null  int64
#  14  Placement_Status      45000 non-null  object
# dtypes: float64(1), int64(10), object(4)
# memory usage: 5.1+ MB

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['Age'])
# Out:
# pandas.core.series.Series

# %%
df.describe()
# Out:
#          Student_ID           Age          CGPA   Internships      Projects  \
# count  45000.000000  45000.000000  45000.000000  45000.000000  45000.000000
# mean   24977.962600     20.999333      7.002290      0.774089      3.734222
# std    14425.605704      1.995071      0.993855      0.844750      0.923738
# min        1.000000     18.000000      4.500000      0.000000      1.000000
# 25%    12509.750000     19.000000      6.320000      0.000000      3.000000
# 50%    24957.500000     21.000000      7.000000      1.000000      4.000000
# 75%    37475.250000     23.000000      7.670000      1.000000      4.000000
# max    50000.000000     24.000000      9.800000      3.000000      6.000000
#
#        Coding_Skills  Communication_Skills  Aptitude_Test_Score  \
# count   45000.000000          45000.000000         45000.000000
# mean        5.691800              5.501644            69.385356
# std         1.994674              1.515374            13.909710
# min         1.000000              1.000000            35.000000
# 25%         4.000000              4.000000            60.000000
# 50%         6.000000              6.000000            69.000000
# 75%         7.000000              7.000000            79.000000
# max        10.000000             10.000000           100.000000
#
#        Soft_Skills_Rating  Certifications      Backlogs
# count        45000.000000    45000.000000  45000.000000
# mean             5.501644        1.800956      0.888133
# std              1.238722        0.650104      0.970954
# min              1.000000        0.000000      0.000000
# 25%              5.000000        1.000000      0.000000
# 50%              5.000000        2.000000      1.000000
# 75%              6.000000        2.000000      2.000000
# max             10.000000        3.000000      3.000000

# %%
df['Coding_Skills'].unique()
# Out:
# array([ 4,  6,  5,  3,  7,  1,  9,  8,  2, 10])

# %%
df['Projects'].unique()
# Out:
# array([3, 4, 2, 5, 6, 1])

# %%
df['Branch'].nunique()
# Out:
# 5

# %%
df['Projects'].nunique()
# Out:
# 6

# %%
df['Aptitude_Test_Score'].max()
# Out:
# 100

# %%
df['Backlogs'].min()
# Out:
# 0

# %%
df['CGPA'].mean()
# Out:
# np.float64(7.0022902222222205)

# %%
marks=df[df['CGPA']>9]
marks
# Out:
#        Student_ID  Age  Gender  Degree Branch  CGPA  Internships  Projects  \
# 56          27410   22    Male    B.Sc  Civil  9.04            1         5
# 68          11116   21  Female  B.Tech  Civil  9.26            2         5
# 81          21290   18    Male     BCA     ME  9.11            2         5
# 87          35364   24    Male  B.Tech    ECE  9.16            2         6
# 88          24709   24  Female    B.Sc     IT  9.15            1         6
# ...           ...  ...     ...     ...    ...   ...          ...       ...
# 44795       48067   23  Female     BCA     IT  9.76            1         5
# 44873       22015   21  Female    B.Sc     ME  9.80            1         6
# 44944       43705   24    Male     MCA    CSE  9.09            0         4
# 44947        7115   24    Male     MCA    CSE  9.51            1         6
# 44967       23354   19    Male     MCA  Civil  9.06            0         5
#
#        Coding_Skills  Communication_Skills  Aptitude_Test_Score  \
# 56                 6                     5                   82
# 68                 8                     5                   90
# 81                 7                     4                   87
# 87                 9                     5                  100
# 88                10                     5                   88
# ...              ...                   ...                  ...
# 44795              8                     6                   85
# 44873             10                     7                   90
# 44944              5                     4                  100
# 44947              9                     5                   82
# 44967              6                     8                   70
#
#        Soft_Skills_Rating  Certifications  Backlogs Placement_Status
# 56                      6               2         0           Placed
# 68                      8               3         0           Placed
# 81                      6               2         0       Not Placed
# 87                      5               3         0           Placed
# 88                      5               3         0           Placed
# ...                   ...             ...       ...              ...
# 44795                   5               3         0           Placed
# 44873                   5               3         0           Placed
# 44944                   6               2         0       Not Placed
# 44947                   5               3         0           Placed
# 44967                   3               2         0           Placed
#
# [1048 rows x 15 columns]

# %%
placement_analysis=df[df['Certifications']>2]
placement_analysis.head(12)
# Out:
#     Student_ID  Age  Gender  Degree Branch  CGPA  Internships  Projects  \
# 11       11924   19    Male     MCA    ECE  7.48            2         5
# 12       11236   19    Male    B.Sc    CSE  7.58            1         5
# 24        2359   24    Male     BCA    CSE  8.47            2         5
# 35        7729   23  Female    B.Sc    ECE  7.83            1         5
# 64       25030   19    Male     MCA    ECE  7.27            1         5
# 68       11116   21  Female  B.Tech  Civil  9.26            2         5
# 69         566   20  Female    B.Sc    ECE  8.21            1         5
# 73       33813   18    Male  B.Tech     IT  7.27            1         5
# 74       13532   20  Female     BCA    CSE  7.56            2         5
# 87       35364   24    Male  B.Tech    ECE  9.16            2         6
# 88       24709   24  Female    B.Sc     IT  9.15            1         6
# 93       30535   20    Male     BCA    CSE  7.38            2         5
#
#     Coding_Skills  Communication_Skills  Aptitude_Test_Score  \
# 11              9                     8                   67
# 12              8                     1                   80
# 24              9                     3                   80
# 35              9                     5                   82
# 64              9                     6                   77
# 68              8                     5                   90
# 69              7                     5                  100
# 73             10                     4                   78
# 74              8                     8                   84
# 87              9                     5                  100
# 88             10                     5                   88
# 93             10                     7                   66
#
#     Soft_Skills_Rating  Certifications  Backlogs Placement_Status
# 11                   6               3         0           Placed
# 12                   8               3         2       Not Placed
# 24                   4               3         0       Not Placed
# 35                   6               3         1           Placed
# 64                   8               3         0           Placed
# 68                   8               3         0           Placed
# 69                   7               3         1           Placed
# 73                   6               3         2       Not Placed
# 74                   5               3         1           Placed
# 87                   5               3         0           Placed
# 88                   5               3         0           Placed
# 93                   4               3         0           Placed

# %%
df[['CGPA', 'Placement_Status']].sort_values(by='CGPA', ascending=False)
# Out:
#        CGPA Placement_Status
# 10100   9.8           Placed
# 22693   9.8           Placed
# 22459   9.8       Not Placed
# 22409   9.8       Not Placed
# 10242   9.8       Not Placed
# ...     ...              ...
# 13027   4.5       Not Placed
# 43593   4.5       Not Placed
# 42787   4.5       Not Placed
# 33031   4.5       Not Placed
# 38894   4.5       Not Placed
#
# [45000 rows x 2 columns]

# %%
df[['Communication_Skills','Coding_Skills']].head(7)
# Out:
#    Communication_Skills  Coding_Skills
# 0                     6              4
# 1                     8              6
# 2                     6              6
# 3                     6              6
# 4                     5              6
# 5                     7              5
# 6                     4              6

# %%
df.loc[120]
# Out:
# Student_ID                   29131
# Age                             20
# Gender                      Female
# Degree                         BCA
# Branch                          ME
# CGPA                          6.38
# Internships                      0
# Projects                         3
# Coding_Skills                    4
# Communication_Skills             5
# Aptitude_Test_Score             61
# Soft_Skills_Rating               5
# Certifications                   1
# Backlogs                         3
# Placement_Status        Not Placed
# Name: 120, dtype: object

# %%
df.loc[120,'Soft_Skills_Rating']
# Out:
# np.int64(5)

# %% [markdown]
# to drop a column(degree) and display the entire dataset

# %%
df.drop(columns=["Degree"], inplace=True, errors='ignore')
display(df)
# Out:
#        Student_ID  Age  Gender Branch  CGPA  Internships  Projects  \
# 0            1048   22  Female    ECE  6.29            0         3
# 1           37820   20  Female    ECE  6.05            1         4
# 2           49668   22    Male     ME  7.22            1         4
# 3           19467   22    Male     ME  7.78            2         4
# 4           23094   20  Female     ME  7.63            1         4
# ...           ...  ...     ...    ...   ...          ...       ...
# 44995        9362   20    Male  Civil  7.84            2         5
# 44996        8940   19  Female     ME  8.28            1         4
# 44997       13097   20  Female  Civil  8.88            0         4
# 44998       12958   24  Female    ECE  5.90            1         3
# 44999        9565   23  Female     ME  6.28            0         4
#
#        Coding_Skills  Communication_Skills  Aptitude_Test_Score  \
# 0                  4                     6                   51
# 1                  6                     8                   59
# 2                  6                     6                   58
# 3                  6                     6                   90
# 4                  6                     5                   79
# ...              ...                   ...                  ...
# 44995              9                     7                   68
# 44996              6                     5                   74
# 44997              4                     5                   83
# 44998              6                     6                   60
# 44999              6                     6                   64
#
#        Soft_Skills_Rating  Certifications  Backlogs Placement_Status
# 0                       5               1         3       Not Placed
# 1                       8               2         1       Not Placed
# 2                       6               2         2       Not Placed
# 3                       4               2         0           Placed
# 4                       6               2         0           Placed
# ...                   ...             ...       ...              ...
# 44995                   6               3         1           Placed
# 44996                   5               2         0           Placed
# 44997                   4               2         0       Not Placed
# 44998                   2               2         1       Not Placed
# 44999                   7               2         3       Not Placed
#
# [45000 rows x 14 columns]

# %% [markdown]
# isnull() --> gives all the null values present in dataset

# %%
df.isnull()
# Out:
#        Student_ID    Age  Gender  Branch   CGPA  Internships  Projects  \
# 0           False  False   False   False  False        False     False
# 1           False  False   False   False  False        False     False
# 2           False  False   False   False  False        False     False
# 3           False  False   False   False  False        False     False
# 4           False  False   False   False  False        False     False
# ...           ...    ...     ...     ...    ...          ...       ...
# 44995       False  False   False   False  False        False     False
# 44996       False  False   False   False  False        False     False
# 44997       False  False   False   False  False        False     False
# 44998       False  False   False   False  False        False     False
# 44999       False  False   False   False  False        False     False
#
#        Coding_Skills  Communication_Skills  Aptitude_Test_Score  \
# 0              False                 False                False
# 1              False                 False                False
# 2              False                 False                False
# 3              False                 False                False
# 4              False                 False                False
# ...              ...                   ...                  ...
# 44995          False                 False                False
# 44996          False                 False                False
# 44997          False                 False                False
# 44998          False                 False                False
# 44999          False                 False                False
#
#        Soft_Skills_Rating  Certifications  Backlogs  Placement_Status
# 0                   False           False     False             False
# 1                   False           False     False             False
# 2                   False           False     False             False
# 3                   False           False     False             False
# 4                   False           False     False             False
# ...                   ...             ...       ...               ...
# 44995               False           False     False             False
# 44996               False           False     False             False
# 44997               False           False     False             False
# 44998               False           False     False             False
# 44999               False           False     False             False
#
# [45000 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# Student_ID              0
# Age                     0
# Gender                  0
# Branch                  0
# CGPA                    0
# Internships             0
# Projects                0
# Coding_Skills           0
# Communication_Skills    0
# Aptitude_Test_Score     0
# Soft_Skills_Rating      0
# Certifications          0
# Backlogs                0
# Placement_Status        0
# dtype: int64

# %%
df['Coding_Skills'].fillna(0, inplace=False)
df.head(8)
# Out:
#    Student_ID  Age  Gender Branch  CGPA  Internships  Projects  Coding_Skills  \
# 0        1048   22  Female    ECE  6.29            0         3              4
# 1       37820   20  Female    ECE  6.05            1         4              6
# 2       49668   22    Male     ME  7.22            1         4              6
# 3       19467   22    Male     ME  7.78            2         4              6
# 4       23094   20  Female     ME  7.63            1         4              6
# 5        8710   20    Male    ECE  7.99            1         4              5
# 6       24363   21    Male    ECE  7.50            1         4              6
# 7       27448   19    Male     ME  8.00            0         4              4
#
#    Communication_Skills  Aptitude_Test_Score  Soft_Skills_Rating  \
# 0                     6                   51                   5
# 1                     8                   59                   8
# 2                     6                   58                   6
# 3                     6                   90                   4
# 4                     5                   79                   6
# 5                     7                   84                   6
# 6                     4                   71                   8
# 7                     5                   74                   3
#
#    Certifications  Backlogs Placement_Status
# 0               1         3       Not Placed
# 1               2         1       Not Placed
# 2               2         2       Not Placed
# 3               2         0           Placed
# 4               2         0           Placed
# 5               2         0           Placed
# 6               2         1       Not Placed
# 7               1         0       Not Placed

# %%
df.dropna().head(8)
# Out:
#    Student_ID  Age  Gender Branch  CGPA  Internships  Projects  Coding_Skills  \
# 0        1048   22  Female    ECE  6.29            0         3              4
# 1       37820   20  Female    ECE  6.05            1         4              6
# 2       49668   22    Male     ME  7.22            1         4              6
# 3       19467   22    Male     ME  7.78            2         4              6
# 4       23094   20  Female     ME  7.63            1         4              6
# 5        8710   20    Male    ECE  7.99            1         4              5
# 6       24363   21    Male    ECE  7.50            1         4              6
# 7       27448   19    Male     ME  8.00            0         4              4
#
#    Communication_Skills  Aptitude_Test_Score  Soft_Skills_Rating  \
# 0                     6                   51                   5
# 1                     8                   59                   8
# 2                     6                   58                   6
# 3                     6                   90                   4
# 4                     5                   79                   6
# 5                     7                   84                   6
# 6                     4                   71                   8
# 7                     5                   74                   3
#
#    Certifications  Backlogs Placement_Status
# 0               1         3       Not Placed
# 1               2         1       Not Placed
# 2               2         2       Not Placed
# 3               2         0           Placed
# 4               2         0           Placed
# 5               2         0           Placed
# 6               2         1       Not Placed
# 7               1         0       Not Placed

# %% [markdown]
# shows the highest cgpa person's entire row

# %%
df.loc[df["CGPA"].idxmax()]
# Out:
# Student_ID                6221
# Age                         22
# Gender                    Male
# Branch                     ECE
# CGPA                       9.8
# Internships                  2
# Projects                     6
# Coding_Skills                9
# Communication_Skills         5
# Aptitude_Test_Score         96
# Soft_Skills_Rating           6
# Certifications               3
# Backlogs                     0
# Placement_Status        Placed
# Name: 685, dtype: object

# %% [markdown]
# shows the lowest(aptitude score) person's whole row

# %%
df.loc[df['Aptitude_Test_Score'].idxmin()]
# Out:
# Student_ID                   48780
# Age                             22
# Gender                        Male
# Branch                          ME
# CGPA                          5.07
# Internships                      0
# Projects                         2
# Coding_Skills                    2
# Communication_Skills             6
# Aptitude_Test_Score             35
# Soft_Skills_Rating               8
# Certifications                   0
# Backlogs                         2
# Placement_Status        Not Placed
# Name: 96, dtype: object

# %% [markdown]
# getting internship column values in descending order
# acending=True --> ascending order,
# ascending=False --> Descendind order

# %%
df['Internships'].sort_values(ascending=False).head(6)
# Out:
# 29316    3
# 29324    3
# 3769     3
# 29217    3
# 29242    3
# 3787     3
# Name: Internships, dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44995    False
# 44996    False
# 44997    False
# 44998    False
# 44999    False
# Length: 45000, dtype: bool

# %%
df.drop_duplicates()
# Out:
#        Student_ID  Age  Gender Branch  CGPA  Internships  Projects  \
# 0            1048   22  Female    ECE  6.29            0         3
# 1           37820   20  Female    ECE  6.05            1         4
# 2           49668   22    Male     ME  7.22            1         4
# 3           19467   22    Male     ME  7.78            2         4
# 4           23094   20  Female     ME  7.63            1         4
# ...           ...  ...     ...    ...   ...          ...       ...
# 44995        9362   20    Male  Civil  7.84            2         5
# 44996        8940   19  Female     ME  8.28            1         4
# 44997       13097   20  Female  Civil  8.88            0         4
# 44998       12958   24  Female    ECE  5.90            1         3
# 44999        9565   23  Female     ME  6.28            0         4
#
#        Coding_Skills  Communication_Skills  Aptitude_Test_Score  \
# 0                  4                     6                   51
# 1                  6                     8                   59
# 2                  6                     6                   58
# 3                  6                     6                   90
# 4                  6                     5                   79
# ...              ...                   ...                  ...
# 44995              9                     7                   68
# 44996              6                     5                   74
# 44997              4                     5                   83
# 44998              6                     6                   60
# 44999              6                     6                   64
#
#        Soft_Skills_Rating  Certifications  Backlogs Placement_Status
# 0                       5               1         3       Not Placed
# 1                       8               2         1       Not Placed
# 2                       6               2         2       Not Placed
# 3                       4               2         0           Placed
# 4                       6               2         0           Placed
# ...                   ...             ...       ...              ...
# 44995                   6               3         1           Placed
# 44996                   5               2         0           Placed
# 44997                   4               2         0       Not Placed
# 44998                   2               2         1       Not Placed
# 44999                   7               2         3       Not Placed
#
# [45000 rows x 14 columns]

# %%
len(df)
# Out:
# 45000

# %% [markdown]
# Data visualization --> graphical representation of data using charts and graphs.
#
#
# *   huge amount of datset --> charts and graphs

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# value_counts --> this shows how many times each unique value has repeated.

# %%
df['Placement_Status'].value_counts()
# Out:
# Placement_Status
# Not Placed    28688
# Placed        16312
# Name: count, dtype: int64

# %% [markdown]
# To see average cgpa of each branch

# %%
highest_cgpa= df.groupby('Branch')['CGPA'].mean()
display(highest_cgpa)
# Out:
# Branch
# CSE      7.006738
# Civil    7.014775
# ECE      7.005899
# IT       6.994024
# ME       6.990065
# Name: CGPA, dtype: float64

# %% [markdown]
# to see average cgpa of each gender

# %%
highest_cgpa_gender=df.groupby('Gender')['CGPA'].mean()
display(highest_cgpa_gender)
# Out:
# Gender
# Female    7.001018
# Male      7.003576
# Name: CGPA, dtype: float64

# %% [markdown]
# to see the highest values of cgpa in each gender

# %%
avg_cgpa_per_department = df.groupby('Branch')['CGPA'].mean()
display(avg_cgpa_per_department)
# Out:
# Branch
# CSE      7.006738
# Civil    7.014775
# ECE      7.005899
# IT       6.994024
# ME       6.990065
# Name: CGPA, dtype: float64

# %% [markdown]
# Line chart --> used to represent trends over time
#
#
# *   How does the average CGPA vary across departments?
#
#
# *  how does aptitude_test_Score vary across age ?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('/content/Placement-success-dashboard-/train.csv')
avg_cgpa_branch=df.groupby('Branch')['CGPA'].mean().sort_values(ascending=False)
plt.figure(figsize=(6,5))
plt.plot(avg_cgpa_branch.index, avg_cgpa_branch.values, color='teal', marker='o',linewidth='2.5')
plt.xlabel('Branch', fontsize=14, color='red')
plt.ylabel('Average CGPA', fontsize=15, color='red')
plt.title('AVERAGE CGPA ACORSS BRANCH', color='red')
plt.tight_layout()
plt.show()

# %%
df=pd.read_csv('/content/Placement-success-dashboard-/train.csv')
avg_aptitude_per_age=df.groupby('Age')['Aptitude_Test_Score'].mean()
plt.figure(figsize=(8,7))
plt.plot(avg_aptitude_per_age.index,avg_aptitude_per_age.values,marker='o', color='blue', linewidth='1.5')
plt.xlabel('Age',fontsize=17, color='green')
plt.ylabel('Aptitude_Test_Score', fontsize=17, color='green',)
plt.title('AVERAGE APTITUDE AMONG DIFFERENT AGE GROUPS', color='green')
plt.grid(True)
plt.show()

# %% [markdown]
# bar plot --> comparing two categories
#
# *   Create a bar chart comparing aptitude_test_score by placement_status.

# %%
avg_aptitude_by_placement = df.groupby('Placement_Status')['Aptitude_Test_Score'].mean().reset_index()
plt.figure(figsize=(8, 8))
plt.bar(avg_aptitude_by_placement['Placement_Status'], avg_aptitude_by_placement['Aptitude_Test_Score'], color=['lightpink','lightblue'])
plt.xlabel('Placement Status', fontsize=12)
plt.ylabel('Average Aptitude Test Score', fontsize=12)
plt.title('Average Aptitude Test Score by Placement Status', fontsize=14)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Pie chart --> used to show proportions
#
# *   What percentage of students got placed?

# %%
import matplotlib.pyplot as plt
placement_counts = df['Placement_Status'].value_counts()
colors = ['lightblue', 'lightpink']
explode = (0.1, 0.001)
plt.figure(figsize=(7, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=colors, explode=explode, shadow=True)
plt.title('Overall Placement Status Proportions', fontsize=17)
plt.show()

# %%
placement_counts = df['Placement_Status'].value_counts()
placement_counts
# Out:
# Placement_Status
# Not Placed    28688
# Placed        16312
# Name: count, dtype: int64

# %% [markdown]
# scatter plot --> used to find the relationship between two variables
#
# *   Does backlogs affect placements alongside aptitude_test_score?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7))
sns.scatterplot(data=df, x='Backlogs', y='Aptitude_Test_Score', hue='Placement_Status', palette={'Placed': 'purple', 'Not Placed': 'lightblue'})
plt.title('Aptitude Test Score vs. Number of Backlogs by Placement Status', fontsize=16)
plt.xlabel('Number of Backlogs', fontsize=12)
plt.ylabel('Aptitude Test Score', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# histogram --> used to show the distribution of variables.
#
# *   distribution of communication skills among the students ?

# %%
plt.figure(figsize=(8,10))
plt.hist(df['Communication_Skills'], bins=10, color='lightgreen', edgecolor='white')
plt.xlabel('Communication_Skills(1 to 10)',fontsize=18)
plt.ylabel('number of students(frequency)',fontsize=18)
plt.title('COMMUNICATION SKILLS AMONG STUDENTS', fontsize=18)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# box plot --> used to understand outliners and medians.
#
# *   How does the total project count differ between placed and non-placed students?

# %%
df[df['Placement_Status']=='Placed']['Projects'].value_counts()
# Out:
# Projects
# 4    9257
# 5    5243
# 3    1065
# 6     747
# Name: count, dtype: int64

# %%
df[df['Placement_Status']=='Not_Placed']['Projects'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
import matplotlib.pyplot as plt
projects_placed = df[df['Placement_Status'] == 'Placed']['Projects']
projects_not_placed = df[df['Placement_Status'] == 'Not Placed']['Projects']

plt.figure(figsize=(8, 6))
plt.boxplot([projects_not_placed, projects_placed], labels=['Not Placed', 'Placed'])
plt.title('Project Count Distribution by Placement Status', fontsize=16)
plt.xlabel('Placement Status', fontsize=12)
plt.ylabel('Number of Projects', fontsize=12)
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_916/36911878.py:6: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([projects_not_placed, projects_placed], labels=['Not Placed', 'Placed'])

# %% [markdown]
# KPI ANALYSIS --> key performance indicator.
#
# *   it converts complex data into simpler data
# *   it supports business decision making

# %% [markdown]
# 1. **total sum** of CGPA. OVERALL CGPA RATE

# %%
df['CGPA'].sum()
# Out:
# np.float64(315103.05999999994)

# %% [markdown]
# 2. **average value** of CGPA()

# %%
df['CGPA'].mean()
# Out:
# np.float64(7.0022902222222205)

# %% [markdown]
# 3. **min and max** values of cgpa()

# %%
min_cgpa= df['CGPA'].min()
max_cgpa= df['CGPA'].max()
print(min_cgpa)
print(max_cgpa)
# Out:
# 4.5
# 9.8

# %% [markdown]
# *   Which department has the highest placement rate?
# *  Which department has the lowest placement rate?

# %% [markdown]
# 1. Total **number of students** present in the dataset

# %%
len(df)
print ("total number of students:", len(df))
# Out:
# total number of students: 45000

# %% [markdown]
# 2. Total **no of placed students** present in the dataset

# %%
placed_students= df[df['Placement_Status'] == 'Placed']
total_placed_Students = len(placed_students)
print("Total number of placed students:", total_placed_Students)
# Out:
# Total number of placed students: 16312

# %% [markdown]
# 3. total **no of not placed students** present in the dataset

# %%
non_placed_students= df[df['Placement_Status'] == 'Not Placed']
total_non_placed_students= len(non_placed_students)
print("Total no of non placed students:", total_non_placed_students)
# Out:
# Total no of non placed students: 28688

# %% [markdown]
# 4. Total **placement rate** of the dataset

# %%
placement_rate = (total_placed_Students / total_stu) * 100
print(f"Total placement rate: {placement_rate:.2f}%")
# Out:
# Total placement rate: 36.25%

# %% [markdown]
# 5. **Average CGP** of the dataset

# %%
average_cgpa= df['CGPA'].mean()
print(average_cgpa)
# Out:
# 7.0022902222222205

# %% [markdown]
# 6. **Average Internships** of the dataset

# %%
average_internships= df['Internships'].mean()
print(average_internships)
# Out:
# 0.7740888888888889

# %% [markdown]
# 7. **Highest placement department** of the dataset (using pivot table)

# %%
pivot = df[df['Placement_Status'] == 'Placed'].pivot_table(
    index='Branch',
    values='Student_ID',
    aggfunc='count')
top_dept  = pivot['Student_ID'].idxmax()
top_count = pivot['Student_ID'].max()
print(f"Highest Placement Department : {top_dept} ({top_count} students)")
# Out:
# Highest Placement Department : CSE (3832 students)

# %%
pivot = df[df['Placement_Status'] == 'Placed']
pivot.head(7)
# Out:
#     Student_ID  Age  Gender  Degree Branch  CGPA  Internships  Projects  \
# 3        19467   22    Male     MCA     ME  7.78            2         4
# 4        23094   20  Female  B.Tech     ME  7.63            1         4
# 5         8710   20    Male     BCA    ECE  7.99            1         4
# 11       11924   19    Male     MCA    ECE  7.48            2         5
# 13       31588   18    Male  B.Tech    ECE  6.74            2         4
# 15        6245   18    Male     BCA    ECE  6.79            0         3
# 18       25157   23    Male  B.Tech    CSE  6.69            1         4
#
#     Coding_Skills  Communication_Skills  Aptitude_Test_Score  \
# 3               6                     6                   90
# 4               6                     5                   79
# 5               5                     7                   84
# 11              9                     8                   67
# 13              7                     6                   73
# 15              5                     5                   81
# 18              8                     7                   68
#
#     Soft_Skills_Rating  Certifications  Backlogs Placement_Status
# 3                    4               2         0           Placed
# 4                    6               2         0           Placed
# 5                    6               2         0           Placed
# 11                   6               3         0           Placed
# 13                   8               2         0           Placed
# 15                   6               2         0           Placed
# 18                   6               2         1           Placed

# %% [markdown]
# 8. **average certifications** of the dataset

# %%
avg_certi= df['Certifications'].mean()
print("total no of average certifiations:", avg_certi)
# Out:
# total no of average certifiations: 1.8009555555555556
